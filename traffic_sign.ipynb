# %%
import os
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import pandas as pd

# %%
sample_dayClip = "/home/atupulazi/personal_projects/traffic-sign-classifier/lisa_sample/sample-dayClip6/frames"
sample_nightClip = "/home/atupulazi/personal_projects/traffic-sign-classifier/lisa_sample/sample-nightClip1/sample-nightClip1/frames"

day_images = os.listdir(sample_dayClip)
night_images = os.listdir(sample_nightClip)

# %%
print(f"How many images are in day images: {len(day_images)}")
print(f"How many images are in day images: {len(night_images)}")
# Out:
# How many images are in day images: 468
# How many images are in day images: 591

# %%
frame_img1 = "/home/atupulazi/personal_projects/traffic-sign-classifier/lisa_sample/sample-dayClip6/frames/dayClip6--00000.jpg"
img1 = mpimg.imread(frame_img1)

plt.imshow(img1)
plt.show()

# %%
fig, ax = plt.subplots(nrows=1, ncols=10, figsize=(30,5))

for i in range(10):
    img = day_images[i] # each image
    img_path = os.path.join(sample_dayClip, img) # combine the image path with the actual img
    show_img = mpimg.imread(img_path) # read the image

    ax[i].imshow(show_img)
    ax[i].axis('off')
plt.show()

# %%
Ann_BOX = ("/home/atupulazi/personal_projects/traffic-sign-classifier/lisa_sample/sample-dayClip6/frameAnnotationsBOX.csv")
df = pd.read_csv(Ann_BOX, sep= ";")
df.head(7)
# Out:
#                           Filename Annotation tag  Upper left corner X  \
# 0  dayTraining/dayClip6--00000.jpg           stop                  506
# 1  dayTraining/dayClip6--00000.jpg       stopLeft                  595
# 2  dayTraining/dayClip6--00001.jpg           stop                  504
# 3  dayTraining/dayClip6--00001.jpg       stopLeft                  591
# 4  dayTraining/dayClip6--00002.jpg           stop                  500
# 5  dayTraining/dayClip6--00003.jpg           stop                  496
# 6  dayTraining/dayClip6--00003.jpg           stop                  787
#
#    Upper left corner Y  Lower right corner X  Lower right corner Y  \
# 0                  354                   518                   372
# 1                  423                   613                   454
# 2                  352                   516                   370
# 3                  424                   612                   446
# ...
